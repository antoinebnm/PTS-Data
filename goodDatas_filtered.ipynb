# %%
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import os

# %%
#Lecture du fichier
datas = pd.read_csv("datasets" + os.sep + "Agribalyse_Synthese.csv", encoding="utf-8", sep=",",index_col=0)

# %%
#Copier le fichier pour le traiter ensuite
dataCopy = datas.copy()
dataCopy.head()
# Out:
#           Code CIQUAL                        Groupe d'aliment
# Code AGB
# 11084           11084  aides culinaires et ingrédients divers  \
# 11023           11023  aides culinaires et ingrédients divers
# 11000           11000  aides culinaires et ingrédients divers
# 11093           11093  aides culinaires et ingrédients divers
# 20995           20995  aides culinaires et ingrédients divers
#
#          Sous-groupe d'aliment
# Code AGB
# 11084                   algues  \
# 11023                   herbes
# 11000                   herbes
# 11093                   herbes
# 20995                   algues
#
#                                  Nom du Produit en Français
# Code AGB
# 11084                                     Agar (algue), cru  \
# 11023                                     Ail séché, poudre
# 11000                                              Ail, cru
# 11093                                          Aneth, frais
# 20995     Ao-nori (Enteromorpha sp.), séchée ou déshydratée
#
#                                                    LCI Name  code saison
# Code AGB
# 11084                                    Seaweed, agar, raw            2  \
# 11023                                 Garlic, powder, dried            2
# 11000                                         Garlic, fresh            2
# 11093                                           Dill, fresh            2
# 20995     Sea lettuce (Enteromorpha sp.), dried or dehyd...            2
#
#           code avion       Livraison Matériau d'emballage         Préparation
# Code AGB
# 11084              0  Ambiant (long)                 LDPE  Pas de préparation  \
# 11023              0  Ambiant (long)                Verre  Pas de préparation
# 11000              0  Ambiant (long)      Pas d'emballage  Pas de préparation
# 11093              0  Ambiant (long)                 LDPE  Pas de préparation
# 20995              0  Ambiant (long)                 LDPE  Pas de préparation
#
#           ...
# Code AGB  ...
# 11084     ...  \
# 11023     ...
# 11000     ...
# 11093     ...
# 20995     ...
#
#           Effets toxicologiques sur la santé humaine : substances cancérogènes
# Code AGB
# 11084                                          6.108019e-09                     \
# 11023                                          4.343632e-10
# 11000                                          2.824785e-10
# 11093                                          5.867577e-10
# 20995                                          6.108019e-09
#
#           Acidification terrestre et eaux douces  Eutrophisation eaux douces
# Code AGB
# 11084                                   0.099733                    0.001868  \
# 11023                                   0.006246                    0.000125
# 11000                                   0.002036                    0.000069
# 11093                                   0.008112                    0.000203
# 20995                                   0.099733                    0.001868
#
#           Eutrophisation marine  Eutrophisation terrestre
# Code AGB
# 11084                  0.013280                  0.127350  \
# 11023                  0.002379                  0.012785
# 11000                  0.002197                  0.006394
# 11093                  0.004050                  0.031181
# 20995                  0.013280                  0.127350
#
#           Écotoxicité pour écosystèmes aquatiques d'eau douce
# Code AGB
# 11084                                             43.368466    \
# 11023                                              5.672531
# 11000                                              4.064650
# 11093                                              5.534832
# 20995                                             43.368466
#
#           Utilisation du sol  Épuisement des ressources eau
# Code AGB
# 11084              24.699395                       3.079121  \
# 11023              20.508995                       2.585763
# 11000              18.871203                       3.104146
# 11093              36.288833                       5.290335
# 20995              24.699395                       3.079121
#
#           Épuisement des ressources énergétiques
# Code AGB
# 11084                                 315.057170  \
# 11023                                  12.701604
# 11000                                   6.275385
# 11093                                  12.553109
# 20995                                 315.057170
#
#           Épuisement des ressources minéraux
# Code AGB
# 11084                               0.000088
# 11023                               0.000007
# 11000                               0.000004
# 11093                               0.000005
# 20995                               0.000088
#
# [5 rows x 28 columns]

# %%
#Enlever le code ciqual car inutile
dataCopy = dataCopy.drop("Code CIQUAL", axis=1)

# %% [markdown]
# Traitement des données qualitatives ordinales

# %%
for i in range(0,len(datas["Livraison"])):
    #print(dataCopy["Livraison"].iloc[i])
    if dataCopy["Livraison"].iloc[i] == "Ambiant (long)":
        dataCopy["Livraison"].iloc[i]=4
    elif dataCopy["Livraison"].iloc[i] == "Glacé":
        dataCopy["Livraison"].iloc[i] = 1
    elif dataCopy["Livraison"].iloc[i] == "Congelé":
        dataCopy["Livraison"].iloc[i] = 0
    elif dataCopy["Livraison"].iloc[i] == "Ambiant (moyen)":
        dataCopy["Livraison"].iloc[i] = 3
    elif dataCopy["Livraison"].iloc[i] == "Ambiant (court)":
        dataCopy["Livraison"].iloc[i] = 2
print("")

# %%
for i in range(0,len(datas["Matériau d'emballage"])):
    #print(dataCopy["Matériau d'emballage"].iloc[i])
    if dataCopy["Matériau d'emballage"].iloc[i] == "Pas d'emballage":
        dataCopy["Matériau d'emballage"].iloc[i]=0
    elif dataCopy["Matériau d'emballage"].iloc[i] == "Verre":
        dataCopy["Matériau d'emballage"].iloc[i]=1
    elif dataCopy["Matériau d'emballage"].iloc[i] == "LDPE":
        dataCopy["Matériau d'emballage"].iloc[i]=2
    elif dataCopy["Matériau d'emballage"].iloc[i] == "Carton":
        dataCopy["Matériau d'emballage"].iloc[i]=3
    elif dataCopy["Matériau d'emballage"].iloc[i] == "Aluminium":
        dataCopy["Matériau d'emballage"].iloc[i]=4
    elif dataCopy["Matériau d'emballage"].iloc[i] == "PVC":
        dataCopy["Matériau d'emballage"].iloc[i]=5
    elif dataCopy["Matériau d'emballage"].iloc[i] == "PS":
        dataCopy["Matériau d'emballage"].iloc[i]=6
    elif dataCopy["Matériau d'emballage"].iloc[i] == "PP":
        dataCopy["Matériau d'emballage"].iloc[i]=7
print("")

# %%
for i in range(0,len(datas["Préparation"])):
    #print(dataCopy["Préparation"].iloc[i])
    if dataCopy["Préparation"].iloc[i] == "Pas de préparation":
        dataCopy["Préparation"].iloc[i]=0
    elif dataCopy["Préparation"].iloc[i] == "Micro-onde " or dataCopy["Préparation"].iloc[i] == "Micro-onde":
        dataCopy["Préparation"].iloc[i]=1
    elif dataCopy["Préparation"].iloc[i] == "Cuisson à l'eau":
        dataCopy["Préparation"].iloc[i]=2
    elif dataCopy["Préparation"].iloc[i] == "Four " or dataCopy["Préparation"].iloc[i] == "Four":
        dataCopy["Préparation"].iloc[i]=3  
    elif dataCopy["Préparation"].iloc[i] == "Réfrigéré chez le consommateur":
        dataCopy["Préparation"].iloc[i]=4
    elif dataCopy["Préparation"].iloc[i] == "Poêle":
        dataCopy["Préparation"].iloc[i]=5 
    elif dataCopy["Préparation"].iloc[i] == "Friture":
        dataCopy["Préparation"].iloc[i]=6 
print("")

# %% [markdown]
# Vérification de la transformation des données qualitatives en données quantitatives

# %%
for j in dataCopy["Préparation"]:
    if type(j)==str:
        print(j)

# %%
for j in dataCopy["Livraison"]:
    if type(j)==str:
        print(j)

# %%
total = 0
for i in dataCopy.columns:
    for j in dataCopy[i]:
        if j == "":
            total += 1
            
print(total)
# Out:
# 0

# %% [markdown]
# Regression linéaire

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X
#    2.67058664   2.81228413   2.1899625    2.69153042   2.64879619
#    2.74941276   2.80451534   3.02300294   2.8031653    2.48568827
#    2.66548618   3.06810132   2.7517103    2.7168742    2.78022932
#    2.82270859   2.77761758   2.73171109   2.77238996   2.92227627
#    2.65934092   2.19634448   2.72082704   2.52571118   2.65051793
#    2.99586814   2.74413976   2.80451534   2.72388371   2.54257901
#    2.7659011    2.54593911   2.63322054   2.91488921   2.80794311
#    2.91488921   2.78264171   2.89474416   2.83032578   3.29551513
#    2.74601738   2.70380515   2.70046957   3.69488058   3.40559911
#    2.69794773   2.8091484    2.74399003   3.73183306   2.7182815
#    2.48645642   2.9094683    2.71822066   2.7273858    3.35771039
#    2.68168167   3.69498446   2.734202     3.22586063   2.69437066
#    2.80215399   2.8212879    2.80646505   3.73183306   2.746092
#    3.59962858   2.79930157   2.81540565   2.62581835   2.76949434
#    2.76041762   2.9092689    2.30996094   2.71207449]

# %%
dataHeatMap = dataCopy.select_dtypes(exclude=['object'])
plt.figure(figsize=(16, 16))
sns.heatmap(dataHeatMap.corr(), annot=True)
plt.show()

# %%
dataCopy.describe()
# Out:
#        code saison   code avion          DQR  Score unique EF
# count  2518.000000  2518.000000  2518.000000      2518.000000  \
# mean      1.997617     0.000794     2.768168         0.674660
# std       0.062987     0.028177     0.553070         0.856597
# min       0.000000     0.000000     1.200000         0.012941
# 25%       2.000000     0.000000     2.380000         0.157586
# 50%       2.000000     0.000000     2.680000         0.349165
# 75%       2.000000     0.000000     3.090000         0.862760
# max       2.000000     1.000000     4.870000         5.813351
#
#        Changement climatique  Appauvrissement de la couche d'ozone
# count            2518.000000                          2.518000e+03  \
# mean                5.352347                          5.295133e-07
# std                 7.605873                          4.873864e-06
# min                 0.039161                          2.711347e-09
# 25%                 1.111978                          1.184973e-07
# 50%                 2.448059                          2.030205e-07
# 75%                 6.222165                          5.523210e-07
# max                50.917912                          2.433486e-04
#
#        Rayonnements ionisants  Formation photochimique d'ozone
# count             2518.000000                      2518.000000  \
# mean                 1.016800                         0.021514
# std                  1.602772                         0.043885
# min                  0.023043                         0.000120
# 25%                  0.301996                         0.003565
# 50%                  0.668826                         0.007197
# 75%                  1.116586                         0.018092
# max                 30.373306                         0.389954
#
#        Particules fines
# count      2.518000e+03  \
# mean       5.722425e-07
# std        8.831605e-07
# min        5.374447e-09
# 25%        8.112941e-08
# 50%        2.373566e-07
# 75%        7.068223e-07
# max        6.190059e-06
#
#        Effets toxicologiques sur la santé humaine : substances non-cancérogènes
# count                                       2.518000e+03                         \
# mean                                        8.106852e-08
# std                                         1.328885e-07
# min                                         1.041913e-09
# 25%                                         1.743184e-08
# 50%                                         3.792691e-08
# 75%                                         7.240328e-08
# max                                         1.546013e-06
#
#        Effets toxicologiques sur la santé humaine : substances cancérogènes
# count                                       2.518000e+03                     \
# mean                                        3.614483e-09
# std                                         4.619379e-09
# min                                         5.612756e-11
# 25%                                         8.915459e-10
# 50%                                         2.181853e-09
# 75%                                         4.657096e-09
# max                                         6.289898e-08
#
#        Acidification terrestre et eaux douces  Eutrophisation eaux douces
# count                             2518.000000                 2518.000000  \
# mean                                 0.078641                    0.000851
# std                                  0.127071                    0.002070
# min                                  0.000490                    0.000013
# 25%                                  0.009368                    0.000202
# 50%                                  0.031714                    0.000445
# 75%                                  0.088815                    0.000865
# max                                  0.912512                    0.032660
#
#        Eutrophisation marine  Eutrophisation terrestre
# count            2518.000000               2518.000000  \
# mean                0.028298                  0.308978
# std                 0.050263                  0.528213
# min                 0.000213                  0.001103
# 25%                 0.005295                  0.033723
# 50%                 0.012962                  0.117878
# 75%                 0.028895                  0.331958
# max                 0.670953                  4.038975
#
#        Écotoxicité pour écosystèmes aquatiques d'eau douce
# count                                        2518.000000    \
# mean                                           52.695938
# std                                            64.363114
# min                                             0.660594
# 25%                                            13.187684
# 50%                                            33.997363
# 75%                                            61.935446
# max                                          1085.818340
#
#        Utilisation du sol  Épuisement des ressources eau
# count         2518.000000                    2518.000000  \
# mean           319.016989                       5.187148
# std            655.840955                      19.500297
# min            -42.220580                    -222.183850
# 25%             33.445734                       0.793924
# 50%            120.790285                       2.057243
# 75%            288.546528                       5.336188
# max           5525.755000                     477.447230
#
#        Épuisement des ressources énergétiques
# count                             2518.000000  \
# mean                                49.166213
# std                                 54.387211
# min                                  1.710196
# 25%                                 19.787166
# 50%                                 30.596413
# 75%                                 61.166026
# max                                710.666870
#
#        Épuisement des ressources minéraux
# count                        2.518000e+03
# mean                         2.101284e-05
# std                          4.273932e-05
# min                          6.177173e-07
# 25%                          7.176604e-06
# 50%                          1.247782e-05
# 75%                          2.388837e-05
# max                          1.286939e-03

# %%
plt.scatter(x=dataCopy['Score unique EF'].values,y = dataCopy['Particules fines'].values,c = dataCopy["DQR"].values, cmap='hsv')
plt.xlabel('Score EF')
plt.ylabel('Nombre de Particules fines')
plt.title('Data Quality Ratio')
plt.colorbar()
plt.show()

# %% [markdown]
# # Régression linéaire multi-variée
#
# Nous allons trouver la relation entre les sales et les différents types d'investissment. Ensuite, nous allons étudier le caractère significatif partiel et total de la regression.

# %%
X_ = dataCopy.select_dtypes(include=['number']).drop("DQR", axis=1)
y_ = datas["DQR"]

#créer un objet reg lin
modeleReg=LinearRegression()

modeleReg.fit(X_,y_)

results = {
 "label":["constante"]+list(X_.columns)+["Score"],
  "coeff": np.concatenate((modeleReg.intercept_.reshape(1,-1), modeleReg.coef_,modeleReg.score(X_,y_)), axis=None),
}

pd.DataFrame(results)
# Out:
#                                                 label         coeff
# 0                                           constante  2.014118e+00
# 1                                         code saison  3.599619e-01
# 2                                          code avion  4.276826e-01
# 3                                     Score unique EF  1.485378e+01
# 4                               Changement climatique -4.630224e-01
# 5                Appauvrissement de la couche d'ozone -1.678690e+04
# 6                              Rayonnements ionisants -2.296004e-01
# 7                     Formation photochimique d'ozone -1.693863e+01
# 8                                    Particules fines -3.867596e+05
# 9   Effets toxicologiques sur la santé humaine : s... -1.213743e+06
# 10  Effets toxicologiques sur la santé humaine : s...  1.876970e+05
# 11             Acidification terrestre et eaux douces -2.478315e+01
# 12                         Eutrophisation eaux douces -2.408376e+02
# 13                              Eutrophisation marine -2.129980e+01
# 14                           Eutrophisation terrestre -4.213782e+00
# 15  Écotoxicité pour écosystèmes aquatiques d'eau ... -6.458430e-03
# 16                                 Utilisation du sol -1.146993e-03
# 17                      Épuisement des ressources eau -1.079597e-01
# 18             Épuisement des ressources énergétiques -1.773639e-02
# 19                 Épuisement des ressources minéraux -1.835623e+04
# 20                                              Score  2.093724e-01

# %% [markdown]
# ## Caractère signicatif conjoint des coefficients
#
# On calcule les caractéristiques en terme de SCE, SCR et SCT de cette régression. Le premier test d'hypothèse consiste à savoir le caractère significatif total de la régression.

# %%
import statistics
#calcul de SCR
SCR =((y_-modeleReg.predict(X_))**2).sum() 
#calcul de SCT
SCT =((y_-statistics.mean(y_))**2).sum() 
#calcul de SCE
SCE =((modeleReg.predict(X_)-statistics.mean(y_))**2).sum() 
n = len(y_)
p = X_.shape[1]
R = SCE/SCT; 
F = (SCE/p)/(SCR/(n-p-1))

results = {
 "label":["SCR"]+["SCE"]+["SCT"]+["Score R2"] + ["Fisher"],
  "coeff": np.concatenate((SCR, SCE,SCT, R, F),axis=None),
}

pd.DataFrame(results)
# Out:
#       label       coeff
# 0       SCR  608.717438
# 1       SCE  161.199305
# 2       SCT  769.916743
# 3  Score R2    0.209372
# 4    Fisher   34.816592

# %% [markdown]
# ## Caractère significatif partiel de la régression
#
# Ensuite, nous allons nous interesser au caractère significatif partiel de la régression. Nous devrons pour cela retrouver la matrice de covariance et retrouver son inverse.
#
# On commence d'abord par retrouver les variables explicatives centrées et réduites. Pour chaque colonne X on retranche la moyenne et on normalise par la variance. Un package scaler de Python permet de faire cette opération.

# %%
# Pour retrouver la matrice de covariance 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler() 
# suppression de la colonne Annual
scale = scaler.set_output(transform="pandas")

# Il faudra toujours trouver les variables centrées et réduites
scaled_db = scale.fit_transform(X_)

# %%
n = scaled_db.shape[0]
p = scaled_db.shape[1]
S = np.zeros((n,p)); 
for i,x in enumerate(X_.columns):
    S[:,i] = np.array(scaled_db[x])
Rxx = np.dot(S.T,S)
print('La matrice de covariance est :')
pd.DataFrame(Rxx)
# Out:
# La matrice de covariance est :
#              0            1            2            3            4
# 0   2518.000000     2.686269    59.390537    54.384901     7.157085  \
# 1      2.686269  2518.000000     4.302413    29.899030    20.444051
# 2     59.390537     4.302413  2518.000000  2373.501812   156.919069
# 3     54.384901    29.899030  2373.501812  2518.000000   117.877375
# 4      7.157085    20.444051   156.919069   117.877375  2518.000000
# 5     52.601459   -17.713765   922.803034   660.580718    71.466299
# 6     39.857207    39.020993  1428.941776  1082.877107   231.855108
# 7     53.632445   -35.083560  2390.715767  2302.238451   155.860630
# 8     46.639056     6.538056  1951.064533  2000.009852    64.749813
# 9     51.776360   -38.510795  2116.216232  2118.021415   127.193319
# 10    53.771650   -17.309957  2389.172273  2326.049534   145.982954
# 11    29.951261   -22.592398   984.510369   740.644089    53.582919
# 12    46.504155   -15.573104  1730.515784  1650.133269   117.692675
# 13    51.281757   -15.827814  2356.245387  2374.760657   107.531402
# 14    59.840490   -16.256391  1673.000945  1610.167383    70.884430
# 15    39.054105   -26.663754  2076.289537  2254.389919    32.488752
# 8   1955.687200   367.714220   864.045331   736.406620
# 9   1784.569664   -64.303912  1490.523445  1260.325589
# 10  2097.405023    76.962376  1394.682770   933.669368
# 11   505.571992  1051.865943   815.505739   534.637838
# 12  1314.465908   124.861434  1222.684513   625.126540
# 13  2291.715330   119.211632  1160.640564   766.895496
# 14  1380.563079   239.120389  1189.546561   824.692044
# 15  2518.000000   233.447340   609.717235   423.150707
# 16   233.447340  2518.000000   218.604274    70.257556
# 17   609.717235   218.604274  2518.000000  1408.783787
# 18   423.150707    70.257556  1408.783787  2518.000000

# %%
oneit_db = dataCopy.copy()
alist = []
mask = []

for i, x in enumerate(oneit_db["Sous-groupe d'aliment"]):
    if x in alist:
        mask.append(False)
    else:
        mask.append(True)
        alist.append(x)

# Apply the mask to create a new DataFrame
filtered_oneit_db = oneit_db[mask]

print(alist)
filtered_oneit_db
# Out:
# ['algues', 'herbes', 'ingrédients divers', 'épices', 'aides culinaires', 'sauces', 'sels', 'condiments', 'denrées destinées à une alimentation particulière', 'céréales et biscuits infantiles', 'laits et boissons infantiles', 'desserts infantiles', 'petits pots salés et plats infantiles', 'boisson alcoolisées', 'boissons sans alcool', 'eaux', 'plats composés', 'feuilletées et autres entrées', 'soupes', 'plats végétariens', 'sandwichs', 'pizzas, tartes et crêpes salées', 'salades composées et crudités', 'fruits', 'fruits à coque et graines oléagineuses', 'légumes', 'pommes de terre et autres tubercules', 'légumineuses', 'glaces', 'desserts glacés', 'sorbets', 'fromages', 'produits laitiers frais et assimilés', 'crèmes et spécialités à base de crème', 'laits', 'beurres', 'huiles et graisses végétales', 'autres matières grasses', 'huiles de poissons', 'margarines', 'pâtes, riz et céréales', 'farines et pâtes à tarte', 'gâteaux et pâtisseries', 'pains et viennoiseries', 'céréales de petit-déjeuner et biscuits', 'chocolats et produits à base de chocolat', 'confiseries non chocolatées', 'confitures et assimilés', 'sucres, miels et assimilés', 'produits à base de poissons et produits de la mer', 'viandes cuites', 'viandes crues', 'poissons crus', 'charcuteries', 'poissons cuits', 'autres produits à base de viande', 'substituts de viande', 'mollusques et crustacés cuits', 'mollusques et crustacés crus', 'œufs', 'substituts de charcuterie']
#                                 Groupe d'aliment
# Code AGB
# 11084     aides culinaires et ingrédients divers  \
# 11023     aides culinaires et ingrédients divers
# 37000     aides culinaires et ingrédients divers
# 11025     aides culinaires et ingrédients divers
# 11172     aides culinaires et ingrédients divers
# ...                                          ...
# 25224                    viandes, œufs, poissons
# 10037                    viandes, œufs, poissons
# 10001                    viandes, œufs, poissons
# 22060                    viandes, œufs, poissons
# 25232                    viandes, œufs, poissons
#
#                   Sous-groupe d'aliment
# Code AGB
# 11084                            algues  \
# 11023                            herbes
# 37000                ingrédients divers
# 11025                            épices
# 11172                  aides culinaires
# ...                                 ...
# 25224              substituts de viande
# 10037     mollusques et crustacés cuits
# 10001      mollusques et crustacés crus
# 22060                              œufs
# 25232         substituts de charcuterie
#
#                                  Nom du Produit en Français
# Code AGB
# 11084                                     Agar (algue), cru  \
# 11023                                     Ail séché, poudre
# 37000                              Base de pizza à la crème
# 11025                                      Cannelle, poudre
# 11172              Court-bouillon pour poissons, déshydraté
# ...                                                     ...
# 25224     Bouchées ou émincé au soja et blé (ne convient...
# 10037     Calmar ou calamar ou encornet, bouilli/cuit à ...
# 10001                    Calmar ou calamar ou encornet, cru
# 22060                                     Oeuf de cane, cru
# 25232        Saucisse végétale au blé ou seitan, préemballé
#
#                                            LCI Name  code saison  code avion
# Code AGB
# 11084                            Seaweed, agar, raw            2           0  \
# 11023                         Garlic, powder, dried            2           0
# 37000                    cream sauce for pizza base            2           0
# 11025                              Cinnamon, powder            2           0
# 11172     Aromatic stock cube, for fish, dehydrated            2           0
# ...                                             ...          ...         ...
# 25224                              Soy-based sliced            2           0
# 10037                 Squid, boiled/cooked in water            2           0
# 10001                                    Squid, raw            2           0
# 22060                                 Duck egg, raw            2           0
# 25232      Plant-based sausage with wheat or seitan            2           0
#
#          Livraison Matériau d'emballage Préparation       DQR  ...
# Code AGB                                                       ...
# 11084            4                    2           0  2.990000  ...  \
# 11023            4                    1           0  4.110000  ...
# 37000            4                    3           0  2.890000  ...
# 11025            4                    1           0  3.370000  ...
# 11172            4                    4           0  3.550000  ...
# ...            ...                  ...         ...       ...  ...
# 25224            1                    7           5  1.963951  ...
# 10037            1                    6           2  3.520000  ...
# 10001            1                    6           0  3.640000  ...
# 22060            3                    3           0  3.410000  ...
# 25232            1                    7           5  2.020572  ...
#
#           Effets toxicologiques sur la santé humaine : substances cancérogènes
# Code AGB
# 11084                                          6.108019e-09                     \
# 11023                                          4.343632e-10
# 37000                                          1.281360e-09
# 11025                                          3.090506e-09
# 11172                                          6.812990e-09
# ...                                                     ...
# 25224                                          1.984023e-09
# 10037                                          4.080865e-09
# 10001                                          3.351617e-09
# 22060                                          3.300173e-09
# 25232                                          2.684058e-09
#
#           Acidification terrestre et eaux douces  Eutrophisation eaux douces
# Code AGB
# 11084                                   0.099733                    0.001868  \
# 11023                                   0.006246                    0.000125
# 37000                                   0.019283                    0.000310
# 11025                                   0.088815                    0.001451
# 11172                                   0.069943                    0.002822
# ...                                          ...                         ...
# 25224                                   0.013444                    0.000553
# 10037                                   0.181748                    0.000255
# 10001                                   0.148832                    0.000265
# 22060                                   0.083581                    0.000825
# 25232                                   0.016733                    0.000550
#
#           Eutrophisation marine  Eutrophisation terrestre
# Code AGB
# 11084                  0.013280                  0.127350  \
# 11023                  0.002379                  0.012785
# 37000                  0.006705                  0.079039
# 11025                  0.069161                  0.554170
# 11172                  0.029954                  0.187664
# ...                         ...                       ...
# 25224                  0.008807                  0.037633
# 10037                  0.043975                  0.480719
# 10001                  0.036439                  0.394305
# 22060                  0.018516                  0.364106
# 25232                  0.013800                  0.067651
#
#           Écotoxicité pour écosystèmes aquatiques d'eau douce
# Code AGB
# 11084                                             43.368466    \
# 11023                                              5.672531
# 37000                                             19.241559
# 11025                                            160.566140
# 11172                                             63.714656
# ...                                                     ...
# 25224                                             49.793218
# 10037                                             23.690577
# 10001                                             21.029986
# 22060                                             78.114795
# 25232                                             27.501891
#
#           Utilisation du sol  Épuisement des ressources eau
# Code AGB
# 11084              24.699395                       3.079121  \
# 11023              20.508995                       2.585763
# 37000              94.993989                       0.449383
# 11025             696.690070                      18.363092
# 11172             112.324030                       9.179842
# ...                      ...                            ...
# 25224             110.728050                       0.816975
# 10037              15.027532                       0.406132
# 10001              12.360117                       0.329260
# 22060             210.514830                       4.368613
# 25232             174.949520                       0.925486
#
#           Épuisement des ressources énergétiques
# Code AGB
# 11084                                 315.057170  \
# 11023                                  12.701604
# 37000                                  23.187248
# 11025                                  71.837424
# 11172                                 710.666870
# ...                                          ...
# 25224                                  95.339030
# 10037                                  99.227548
# 10001                                  76.736600
# 22060                                  20.734338
# 25232                                  53.647541
#
#           Épuisement des ressources minéraux
# Code AGB
# 11084                               0.000088
# 11023                               0.000007
# 37000                               0.000017
# 11025                               0.000115
# 11172                               0.000060
# ...                                      ...
# 25224                               0.000013
# 10037                               0.000023
# 10001                               0.000018
# 22060                               0.000011
# 25232                               0.000010
#
# [61 rows x 27 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler() 
# suppression des colonnes string
db = filtered_oneit_db.drop(columns = ["Groupe d'aliment","Sous-groupe d'aliment","Nom du Produit en Français","LCI Name","Matériau d'emballage"])
scale = scaler.set_output(transform="pandas")

# Il faudra toujours trouver les variables centrées et réduites
scaled_db = scale.fit_transform(db)

pca = PCA()
pca.fit(scaled_db)
# Out:
# PCA()

# %%
eig = pd.DataFrame(
    {
        "Dimension" : ["Dim" + str(x + 1) for x in range(22)], 
        "Variance expliquée" : pca.explained_variance_,
        "% variance expliquée" : np.round(pca.explained_variance_ratio_ * 100),
        "% cum. var. expliquée" : np.round(np.cumsum(pca.explained_variance_ratio_) * 100)
    }
)
eig
# Out:
#    Dimension  Variance expliquée  % variance expliquée  % cum. var. expliquée
# 0       Dim1        1.107703e+01                  54.0                   54.0
# 1       Dim2        2.445150e+00                  12.0                   67.0
# 2       Dim3        1.853258e+00                   9.0                   76.0
# 3       Dim4        1.404057e+00                   7.0                   83.0
# 4       Dim5        9.909232e-01                   5.0                   87.0
# 5       Dim6        7.357993e-01                   4.0                   91.0
# 6       Dim7        5.785621e-01                   3.0                   94.0
# 7       Dim8        5.108296e-01                   3.0                   96.0
# 8       Dim9        3.188786e-01                   2.0                   98.0
# 9      Dim10        2.174445e-01                   1.0                   99.0
# 10     Dim11        1.067868e-01                   1.0                  100.0
# 11     Dim12        4.957235e-02                   0.0                  100.0
# 12     Dim13        2.073528e-02                   0.0                  100.0
# 13     Dim14        1.068573e-02                   0.0                  100.0
# 14     Dim15        8.354412e-03                   0.0                  100.0
# 15     Dim16        3.743338e-03                   0.0                  100.0
# 16     Dim17        1.156553e-03                   0.0                  100.0
# 17     Dim18        2.855641e-04                   0.0                  100.0
# 18     Dim19        8.125272e-05                   0.0                  100.0
# 19     Dim20        2.407341e-17                   0.0                  100.0
# 20     Dim21        4.991121e-33                   0.0                  100.0
# 21     Dim22        0.000000e+00                   0.0                  100.0

# %%
eig.plot.bar(x = "Dimension", y = "% variance expliquée") # permet un diagramme en barres
plt.text(5, 18, "10%") # ajout de texte
plt.axhline(y = 10, linewidth = .5, color = "dimgray", linestyle = "--") # ligne 17 = 100 / 6 (nb dimensions)
plt.show()

# %%
db_pca = pca.transform(scaled_db)

# %%
# Transformation en DataFrame pandas
data_pca_df = pd.DataFrame({
    "Dim1" : db_pca[:,0], 
    "Dim2" : db_pca[:,1],
    "G Al" : filtered_oneit_db["Groupe d'aliment"],
    "SG Al" : filtered_oneit_db["Sous-groupe d'aliment"],
    "Mat" : filtered_oneit_db["Matériau d'emballage"],
})

# Résultat
data_pca_df
# Out:
#               Dim1      Dim2                                    G Al
# Code AGB
# 11084     2.181328  4.408510  aides culinaires et ingrédients divers  \
# 11023    -2.088389  0.154535  aides culinaires et ingrédients divers
# 37000    -1.636502 -0.177103  aides culinaires et ingrédients divers
# 11025     3.078562  1.775150  aides culinaires et ingrédients divers
# 11172     3.926475  8.897861  aides culinaires et ingrédients divers
# ...            ...       ...                                     ...
# 25224    -0.696377 -0.039891                 viandes, œufs, poissons
# 10037     1.613540  1.025149                 viandes, œufs, poissons
# 10001     0.815429  0.773115                 viandes, œufs, poissons
# 22060    -0.301784 -0.280707                 viandes, œufs, poissons
# 25232    -0.824115 -0.583458                 viandes, œufs, poissons
#
#                                   SG Al Mat
# Code AGB
# 11084                            algues   2
# 11023                            herbes   1
# 37000                ingrédients divers   3
# 11025                            épices   1
# 11172                  aides culinaires   4
# ...                                 ...  ..
# 25224              substituts de viande   7
# 10037     mollusques et crustacés cuits   6
# 10001      mollusques et crustacés crus   6
# 22060                              œufs   3
# 25232         substituts de charcuterie   7
#
# [61 rows x 5 columns]

# %%
# utilisation de subplots nécessaire car annotation du graphique
fig, ax = plt.subplots()
fig.suptitle("Dimensions réduites")
data_pca_df.plot.scatter("Dim1", "Dim2", ax = ax) # l'option ax permet de placer les points et le texte sur le même graphique
# Ajout des axes
ax.axvline(x = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
ax.axhline(y = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
# boucle sur chaque pays
for k in data_pca_df.iterrows():
    # annotation uniquement si valeur absolue sur une de 2 dimensions importantes (valeurs choisies empiriquement)
        ax.annotate(k[1]["SG Al"], (k[1]['Dim1'], k[1]['Dim2']), fontsize = 9)
plt.xlabel("Dimension 1 (54%)") 
plt.ylabel("Dimension 2 (12%)")
plt.suptitle("Premier plan factoriel (66%)")
plt.show()

# %%
n = db.shape[0] # nb individus
p = db.shape[1] # nb variables

print(n)
eigval = (n-1) / n * pca.explained_variance_ # valeurs propres
sqrt_eigval = np.sqrt(eigval) # racine carrée des valeurs propres
corvar = np.zeros((p,p)) # matrice vide pour avoir les coordonnées
for k in range(p):
    corvar[:,k] = pca.components_[k,:] * sqrt_eigval[k]
# on modifie pour avoir un dataframe
coordvar = pd.DataFrame({'id': db.columns, 'COR_1': corvar[:,0], 'COR_2': corvar[:,1]})
coordvar
# Out:
# 61
#                                                    id         COR_1
# 0                                         code saison  0.000000e+00  \
# 1                                          code avion  3.664651e-16
# 2                                           Livraison -3.128072e-01
# 3                                         Préparation  2.945942e-01
# 4                                                 DQR -2.416461e-03
# 5                                     Score unique EF  9.950086e-01
# 6                               Changement climatique  9.499730e-01
# 7                Appauvrissement de la couche d'ozone  6.690060e-01
# 8                              Rayonnements ionisants  2.851502e-01
# 9                     Formation photochimique d'ozone  6.253334e-01
# 10                                   Particules fines  9.497464e-01
# 11  Effets toxicologiques sur la santé humaine : s...  9.374540e-01
# 12  Effets toxicologiques sur la santé humaine : s...  9.613526e-01
# 13             Acidification terrestre et eaux douces  9.355272e-01
# 14                         Eutrophisation eaux douces  8.753818e-01
# 15                              Eutrophisation marine  5.575911e-01
# 16                           Eutrophisation terrestre  9.260304e-01
# 17  Écotoxicité pour écosystèmes aquatiques d'eau ...  7.979219e-01
# 18                                 Utilisation du sol  8.967950e-01
# 19                      Épuisement des ressources eau  5.220163e-01
# 20             Épuisement des ressources énergétiques  4.533536e-01
# 21                 Épuisement des ressources minéraux  6.815088e-01
#
#            COR_2
# 0  -0.000000e+00
# 1  -1.721764e-16
# 2   1.709136e-01
# 3  -5.075738e-02
# 4   3.806368e-01
# 5  -1.523621e-02
# 6  -1.576970e-01
# 7   3.954622e-01
# 8   8.172643e-01
# 9   1.872945e-01
# 10 -2.207601e-01
# 11 -1.950511e-01
# 12 -1.193812e-01
# 13 -2.586118e-01
# 14  2.658637e-01
# 15  1.403931e-01
# 16 -3.109977e-01
# 17 -2.295297e-02
# 18 -3.621887e-01
# 19  6.048624e-02
# 20  8.250681e-01
# 21  4.156607e-01

# %%
# Création d'une figure vide (avec des axes entre -1 et 1 + le titre)

pal = sns.color_palette("Paired")
couleurs = dict(zip(coordvar["id"], pal))
fig, axes = plt.subplots(figsize = (9,9))
fig.suptitle("Cercle des corrélations")
axes.set_xlim(-1, 1)
axes.set_ylim(-1, 1)
# Ajout des axes
axes.axvline(x = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
axes.axhline(y = 0, color = 'lightgray', linestyle = '--', linewidth = 1)
# Ajout des noms des variables
for j in range(12):
    #axes.text(coordvar["COR_1"][j] ,coordvar["COR_2"][j], coordvar["id"][j],color='red')
    plt.arrow(0, 0,
              coordvar["COR_1"][j],
              coordvar["COR_2"][j],
              color=couleurs[coordvar["id"][j]],
              label = coordvar["id"][j],
              head_width = 0.01,
              width=0.0001,
             )
# Ajout du cercle
plt.gca().add_artist(plt.Circle((0,0),1,color='blue',fill=False))
plt.legend()
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

labelList = list(filtered_oneit_db["Sous-groupe d'aliment"])
Z2 = linkage(db, method='ward', metric='euclidean')
plt.figure(figsize=(39, 36))
dendrogram(
    Z2,
    leaf_rotation= 90,
    labels=labelList,
    distance_sort='ascending',
    show_leaf_counts=False,
    leaf_font_size=16
)
plt.show()

# %%
from sklearn.cluster import KMeans
# n_init='auto' ==> retirer message d'erreur

kmeansn = KMeans(n_clusters = 2, n_init='auto')
kmeansn.fit(db)
kmeansn.cluster_centers_
# Out:
# array([[2.00000000e+00, 0.00000000e+00, 2.61016949e+00, 8.13559322e-01,
#         2.87800033e+00, 5.05944137e-01, 3.93951120e+00, 3.72291429e-07,
#         1.53458725e+00, 1.70670492e-02, 3.75668784e-07, 4.77280132e-08,
#         2.58330483e-09, 4.84808610e-02, 5.45974581e-04, 2.73010147e-02,
#         1.81438094e-01, 4.11709263e+01, 1.85481796e+02, 3.08266287e+00,
#         5.63761615e+01, 1.76517032e-05],
#        [2.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.50000000e+00,
#         2.64000000e+00, 5.19517290e+00, 4.55429870e+01, 1.03582075e-06,
#         1.68083655e+00, 7.34168980e-02, 5.54298045e-06, 6.96431875e-07,
#         2.33643785e-08, 8.17224020e-01, 2.99758035e-03, 1.78428960e-01,
#         3.61766385e+00, 2.08885788e+02, 4.94699590e+03, 1.39202185e+01,
#         1.11279049e+02, 5.58944280e-05]])

# %%
pd.Series(kmeansn.labels_).value_counts()
# Out:
# 0    59
# 1     2
# Name: count, dtype: int64

# %%
db_kn = db.assign(classe = kmeansn.labels_)
db_kn.groupby("classe").mean()
# Out:
#         code saison  code avion Livraison Préparation    DQR  Score unique EF
# classe
# 0               2.0         0.0  2.610169    0.813559  2.878         0.505944  \
# 1               2.0         0.0       1.0         1.5  2.640         5.195173
#
#         Changement climatique  Appauvrissement de la couche d'ozone
# classe
# 0                    3.939511                          3.722914e-07  \
# 1                   45.542987                          1.035821e-06
#
#         Rayonnements ionisants  Formation photochimique d'ozone  ...
# classe                                                           ...
# 0                     1.534587                         0.017067  ...  \
# 1                     1.680837                         0.073417  ...
#
#         Effets toxicologiques sur la santé humaine : substances cancérogènes
# classe
# 0                                            2.583305e-09                     \
# 1                                            2.336438e-08
#
#         Acidification terrestre et eaux douces  Eutrophisation eaux douces
# classe
# 0                                     0.048481                    0.000546  \
# 1                                     0.817224                    0.002998
#
#         Eutrophisation marine  Eutrophisation terrestre
# classe
# 0                    0.027301                  0.181438  \
# 1                    0.178429                  3.617664
#
#         Écotoxicité pour écosystèmes aquatiques d'eau douce
# classe
# 0                                               41.170926    \
# 1                                              208.885788
#
#         Utilisation du sol  Épuisement des ressources eau
# classe
# 0               185.481796                       3.082663  \
# 1              4946.995900                      13.920219
#
#         Épuisement des ressources énergétiques
# classe
# 0                                    56.376162  \
# 1                                   111.279049
#
#         Épuisement des ressources minéraux
# classe
# 0                                 0.000018
# 1                                 0.000056
#
# [2 rows x 22 columns]

# %%
db_pca_kn = data_pca_df.assign(classe = kmeansn.labels_, sg = dataCopy["Sous-groupe d'aliment"])

coul_kmeans = dict(zip(db_pca_kn["classe"].unique(), (range(4))))

fig, ax = plt.subplots()

db_pca_kn.plot('Dim1', 'Dim2', kind='scatter', c = "classe",cmap = "Accent", ax=ax)

print(db_pca_kn.iterrows())
for index, row in db_pca_kn.iterrows():
    ax.annotate(row['sg'], (row['Dim1'], row['Dim2']))

plt.show()
# Out:
# <generator object DataFrame.iterrows at 0x138aaf780>

# %%
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, init = "random", n_init = 20).fit(db)
    inertia = inertia + [kmeans.inertia_]
inertia = pd.DataFrame({"k": range(1, 11), "inertia": inertia})
inertia.plot.line(x = "k", y = "inertia")
plt.scatter(2, inertia.query('k == 2')["inertia"], c = "red")
plt.scatter(3, inertia.query('k == 3')["inertia"], c = "red")
plt.show()
